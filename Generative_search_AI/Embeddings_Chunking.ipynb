# %%
# !pip install wikipedia-api
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1029d0910>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/wikipedia-api/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1029d1270>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/wikipedia-api/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1029d1510>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/wikipedia-api/
# ...

# %%
import numpy as np
import pandas as pd
import wikipediaapi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import wikipediaapi
#
# ModuleNotFoundError: No module named 'wikipediaapi'

# %%
string='Semantic_Search_Taran'
wiki=wikipediaapi.Wikipedia(user_agent=string,language='en')

# %%
page=wiki.page('The Shawshank Redemption')

# %%
print(page)
# Out:
# The Shawshank Redemption (id: ??, ns: 0)

# %%
page.text
# Out:
# 'The Shawshank Redemption is a 1994 American prison drama film written and directed by Frank Darabont, based on the 1982 Stephen King novella Rita Hayworth and Shawshank Redemption. The film tells the story of banker Andy Dufresne (Tim Robbins), who is sentenced to life in Shawshank State Penitentiary for the murders of his wife and her lover, despite his claims of innocence. Over the following two decades, he befriends a fellow prisoner, contraband smuggler Ellis "Red" Redding (Morgan Freeman), and becomes instrumental in a money laundering operation led by the prison warden Samuel Norton (Bob Gunton). William Sadler, Clancy Brown, Gil Bellows, and James Whitmore appear in supporting roles.\nDarabont purchased the film rights to King\'s story in 1987, but development did not begin until five years later, when he wrote the script over an eight-week period. Two weeks after submitting his script to Castle Rock Entertainment, Darabont secured a $25 million budget to produce The Shawshan
# ...

# %%
page.sections[0]
# Out:
# Section: Plot (1):
# In early 1947, Portland, Maine, banker Andy Dufresne arrives at Shawshank State Prison to serve two consecutive life sentences for murdering his wife and her lover. He is befriended by Ellis "Red" Redding, a contraband smuggler serving a life sentence, who procures a rock hammer and a large poster of Rita Hayworth for Andy. Assigned to work in the prison laundry, Andy is frequently sexually assaulted by "the Sisters" and their leader, Bogs Diamond.
# ...

# %% [markdown]
# ### Fixed Size Chunking

# %% [markdown]
# Here we define a chunk size and chunk in windows

# %% [markdown]
# Main Function: **process_page**

# %%
# Function to extract and store Wikipedia page information

def process_page(page_title):

    page = wiki.page(page_title)

    if page.exists():
        page_text = page.text
        chunk_size = 1000  # Set your desired chunk size (in characters)

        text_chunks = split_text_into_chunks(page_text, chunk_size)

        # Create a DataFrame to store the chunks and page title
        data = {'Title': [], 'Chunk Text': []}

        for idx, chunk in enumerate(text_chunks):
            data['Title'].append(page_title)
            data['Chunk Text'].append(chunk)

        return pd.DataFrame(data)

    else:
        print(f"The page '{page_title}' does not exist on Wikipedia.")
        return None

# %% [markdown]
# Helper function: **chunks_split**

# %%
# Function to split text into fixed-size chunks

def split_text_into_chunks(text, chunk_size):
    chunks = []
    words = text.split()  # Split the text into words

    current_chunk = []  # Store words for the current chunk
    current_chunk_word_count = 0  # Count of words in the current chunk

    for word in words:
        if current_chunk_word_count + len(word) + 1 <= chunk_size:
            current_chunk.append(word)
            current_chunk_word_count += len(word) + 1
        else:
            chunks.append(' '.join(current_chunk))
            current_chunk = [word]
            current_chunk_word_count = len(word)

    if current_chunk:
        chunks.append(' '.join(current_chunk))

    return chunks

# %%
# Iterating over all page titles to create the final df with individual chunks

page_titles = ["The Shawshank Redemption", "The Dark Knight", "Pulp Fiction", "The Godfather", "Goodfellas"]

all_dfs = []

for title in page_titles:
    df = process_page(title)
    if df is not None:
        all_dfs.append(df)


fixed_chunk_df = pd.concat(all_dfs, ignore_index=True)
fixed_chunk_df
# Out:
#                         Title  \
# 0    The Shawshank Redemption
# 1    The Shawshank Redemption
# 2    The Shawshank Redemption
# 3    The Shawshank Redemption
# 4    The Shawshank Redemption
# ..                        ...
# 272                Goodfellas
# 273                Goodfellas
# 274                Goodfellas
# 275                Goodfellas
# 276                Goodfellas
#
#                                             Chunk Text
# 0    The Shawshank Redemption is a 1994 American pr...
# 1    Redemption, which started pre-production in Ja...
# 2    It went on to receive multiple award nominatio...
# 3    National Film Registry, finding it "culturally...
# 4    use Andy's financial expertise to manage finan...
# ..                                                 ...
# 272  ranked the film No. 4 on their list of the 10 ...
# 273  ... as opposed to say The Godfather ... which ...
# 274  executive produce with the film's producer Irw...
# ...

# %%
len(fixed_chunk_df.iloc[10][1])
# Out:
# 999

# %% [markdown]
# Chunks by Sections

# %%
def extract_wiki_sections(page_title):
  page=wiki.page(page_title)

  if page.exists():
    title=page.title
    sections=[]

    intro=page.summary
    if intro:
      sections.append(("Introduction",intro))

    def recursive_extraction(section):
      section_text=section.text
      if section_text:
        sections.append((section.title,section_text))
      for sub_section in section.sections:
        recursive_extraction(sub_section)

    for section in page.sections:

# %%
# Install the sentence transformers library

# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 64.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 86.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.0 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=ed4e025b8741d9cfe768635f39d8b723f8ae2e3c303ad5769b3daff35425aa52
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...

# %%
from sentence_transformers import SentenceTransformer, util

# %%
model_name='all-MiniLM-L6-v2'
embedder=SentenceTransformer(model_name)

# %%
# Function to generate embeddings for text
def generate_embeddings(texts):
    embeddings = embedder.encode(texts, convert_to_tensor=True)
    return embeddings

# %%
def generate_embeddings_on_df(df):
  df['Embeddings'] = df['Chunk Text'].apply(lambda x: generate_embeddings([x])[0])

# %%
# Create embeddings for 'Chunk Text' column on all three dataframes

generate_embeddings_on_df(fixed_chunk_df)

# %%
fixed_chunk_df
# Out:
#                         Title  \
# 0    The Shawshank Redemption
# 1    The Shawshank Redemption
# 2    The Shawshank Redemption
# 3    The Shawshank Redemption
# 4    The Shawshank Redemption
# ..                        ...
# 272                Goodfellas
# 273                Goodfellas
# 274                Goodfellas
# 275                Goodfellas
# 276                Goodfellas
#
#                                             Chunk Text  \
# 0    The Shawshank Redemption is a 1994 American pr...
# 1    Redemption, which started pre-production in Ja...
# 2    It went on to receive multiple award nominatio...
# 3    National Film Registry, finding it "culturally...
# 4    use Andy's financial expertise to manage finan...
# ..                                                 ...
# 272  ranked the film No. 4 on their list of the 10 ...
# 273  ... as opposed to say The Godfather ... which ...
# 274  executive produce with the film's producer Irw...
# ...

# %%
fixed_chunk_df.to_csv("fixed_chunk_embeddings.csv", index=False)

# %%
# Read user input query
user_query = input()
